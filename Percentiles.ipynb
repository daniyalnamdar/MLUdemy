# %%
import numpy as np
import matplotlib.pyplot as plt

value = np.random.normal(10, 0.5, 10000)

plt.hist(value, 50)
plt.show()

# %%
np.percentile(value, 50)
# Out:
# 10.00263847493789

# %%
np.percentile(value, 20)
# Out:
# 9.573648405632555

# %%
np.percentile(value, 80)
# Out:
# 10.432842371210494
