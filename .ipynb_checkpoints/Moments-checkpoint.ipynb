# %%
import numpy as np 
import matplotlib.pyplot as plt

vals = np.random.normal(0, 0.5, 10000)

plt.hist(vals, 50)
plt.show()

# %%
np.mean(vals)
# Out:
# 0.0030176723410106263

# %%
np.var(vals)
# Out:
# 0.25889289391299575
