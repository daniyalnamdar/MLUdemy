# %%
import numpy as np
import matplotlib.pyplot as plt


incomes = np.random.normal(100, 20, 1000)

plt.hist(incomes, 50)
plt.show()

# %%
incomes.std()
# Out:
# 20.15880609285531

# %%
incomes.var()
# Out:
# 406.3774630893404

# %% [markdown]
# AcTivity

# %%
import numpy as np
import matplotlib.pyplot as plt


incomes = np.random.normal(100, 200, 1000)

plt.hist(incomes, 100)
plt.show()

# %%
incomes.std()
# Out:
# 200.71528068870722
